# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

# %%
my_file = "sample_data/out_20201013/96_sig.csv"
aux_file = "src/auxiliary_file/COSMIC_NEW.tsv"

my_df = pd.read_csv(my_file, index_col=0)
aux_df = pd.read_csv(aux_file, sep="\t",index_col=0)

# %%
X = np.array(my_df.T.to_numpy())
Y = np.array(aux_df.T.to_numpy())
M = cosine_similarity(X, Y, dense_output=True)

# %%
M.shape
# Out:
# (10, 72)

# %%
M
# Out:
# array([[0.62604766, 0.04098888, 0.22052603, 0.06725689, 0.38940741,
#         0.87490547, 0.12816464, 0.17617749, 0.02980017, 0.06690963,
#         0.06377895, 0.15168616, 0.02953157, 0.50730024, 0.24301683,
#         0.07712732, 0.06101919, 0.08122331, 0.76771123, 0.08395982,
#         0.02872261, 0.00759979, 0.14795047, 0.28236388, 0.22521037,
#         0.10743516, 0.05293176, 0.39791118, 0.26052601, 0.28392238,
#         0.11577083, 0.08557637, 0.01857727, 0.17291164, 0.24667737,
#         0.1385527 , 0.26549258, 0.05970544, 0.03377503, 0.12480264,
#         0.05192447, 0.11025546, 0.0273269 , 0.18264529, 0.196309  ,
#         0.16182153, 0.4575813 , 0.05313253, 0.5485572 , 0.01975242,
#         0.12421457, 0.04699015, 0.01653607, 0.01592204, 0.09814676,
#         0.11553681, 0.02190743, 0.07401959, 0.11017217, 0.07932437,
#         0.0155131 , 0.10006714, 0.10686551, 0.01499107, 0.04588628,
#         0.54058606, 0.0416645 , 0.14056628, 0.50990168, 0.07097927,
# ...

# %%
aux_list = aux_df.columns
my_list = my_df.columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns
height, length = len(my_list), len(aux_list)
f, ax = plt.subplots(figsize=(20,6))
ax = sns.heatmap(M, vmin=0, vmax=1, xticklabels =aux_list, yticklabels = my_list, 
                       square=True, cmap="Blues",
                       cbar_kws={"orientation": "vertical",'shrink':0.5})
ax.set_title('Cosine Similarity Plot',fontsize=18,weight='bold')
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right',fontweight='light', fontsize=7)
ax.set_yticklabels(ax.get_yticklabels(),fontweight='light', fontsize=7)
plt.ylim(bottom=0, top=height+0.5)
plt.savefig("S2S.png",dpi=300,bbox_inches='tight')
print(colored(("=> Generate Cosine Similarity Plot: "+folder+"S2S.png"), 'green'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-168-9ffa8726ad8c> in <module>
#      11 plt.ylim(bottom=0, top=height+0.5)
#      12 plt.savefig("S2S.png",dpi=300,bbox_inches='tight')
# ---> 13 print(colored(("=> Generate Cosine Similarity Plot: "+folder+"S2S.png"), 'green'))
#
# NameError: name 'colored' is not defined

# %%
Mdf= pd.DataFrame(M)
Mdf.index, Mdf.columns = my_list, aux_list

# %%
Mdf
# Out:
#                  SBS1      SBS2      SBS3      SBS4      SBS5      SBS6  \
# Signature_0  0.626048  0.040989  0.220526  0.067257  0.389407  0.874905
# Signature_1  0.084613  0.556750  0.537001  0.260258  0.594247  0.312427
# Signature_2  0.455862  0.055036  0.525758  0.277448  0.555337  0.512860
# Signature_3  0.515053  0.120782  0.262723  0.089892  0.416308  0.730001
# Signature_4  0.483745  0.046880  0.231395  0.065717  0.401566  0.807190
# Signature_5  0.152683  0.369848  0.571657  0.283172  0.540132  0.385280
# Signature_6  0.247950  0.275420  0.678634  0.345845  0.658552  0.425482
# Signature_7  0.344830  0.072500  0.566171  0.231920  0.595499  0.623340
# Signature_8  0.292757  0.058844  0.576089  0.352010  0.590015  0.361803
# Signature_9  0.122440  0.147631  0.469591  0.225973  0.508306  0.464113
#
#                 SBS7a     SBS7b     SBS7c     SBS7d  ...     SBS58     SBS59  \
# Signature_0  0.128165  0.176177  0.029800  0.066910  ...  0.106866  0.014991
# ...

# %%
COLOR_MAP = ['#266199','#b7d5ea','#acc6aa','#E0CADB','#695D73','#B88655','#DDDDDD','#71a0a5','#841D22','#E08B69']

import matplotlib.pyplot as pltd
df = pd.read_csv("sample_data/out_20201013/sig_sample.csv", index_col=0)
raw_data = df.sum(axis=1)/df.shape[1]
SUM = raw_data.sum(axis=0)
raw_data = raw_data/SUM
names, sizes = list(raw_data.index), list(raw_data.iloc[:])
my_circle = pltd.Circle( (0,0), 0.6, color='white')
pltd.pie(sizes, labels=names, colors=COLOR_MAP[:len(names)], autopct='%1.1f%%',textprops={'fontsize': 12},radius=1, pctdistance=1-0.4/2)
p = pltd.gcf()
p.gca().add_artist(my_circle)
pltd.savefig("donut_plot.png", dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(sizes, colors=COLOR_MAP[:len(names)], autopct='%1.1f%%',textprops={'fontsize': 12},radius=1, pctdistance=1-0.4/2)
ax.legend(wedges, list(df.index),
          title="Signature",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
p = plt.gcf()
my_circle = plt.Circle( (0,0), 0.6, color='white')
p.gca().add_artist(my_circle)
p.savefig(pic+"Donut_plot.png", dpi=300, bbox_inches='tight')
print(colored(("=> Generate Donut Plot: "+pic+"Donut_plot.png"), 'green'))
